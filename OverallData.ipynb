# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\presw\Documents\Scouting Report/IBA_Pitchers.xlsx")

# %%
for x in df.index:
    if df.loc[x, "PitcherID"] != int(321):
        df.drop(x, inplace=True)


df
# Out:
#       Unnamed: 0  Season  BatterID BatterSide  PitcherID PitcherThrows  \
# 1346        1347    2022       984       Left        321         Right
# 1347        1348    2022        54      Right        321         Right
# 1348        1349    2022       664      Right        321         Right
# 1349        1350    2022       760      Right        321         Right
# 1350        1351    2022        98      Right        321         Right
# ...          ...     ...       ...        ...        ...           ...
# 2131        2132    2023        16       Left        321         Right
# 2132        2133    2023        16       Left        321         Right
# 2133        2134    2023        16       Left        321         Right
# 2134        2135    2023        16       Left        321         Right
# 2135        2136    2023        16       Left        321         Right
#
#       Inning  Outs  Balls  Strikes  ... PlateLocSide VertApprAngle  \
# 1346       8     2      1        0  ...      0.42778     -6.046808
# 1347       6     2      1        2  ...     -1.00531     -7.658584
# 1348       9     1      0        0  ...      0.14587     -7.136109
# 1349       8     1      2        1  ...     -0.13805     -5.613188
# 1350       4     2      0        1  ...      1.43701     -6.625963
# ...      ...   ...    ...      ...  ...          ...           ...
# 2131       9     2      0        0  ...     -0.84500     -6.194127
# 2132       9     2      1        0  ...      0.85158     -5.508057
# 2133       9     2      1        1  ...     -0.02682     -8.957161
# 2134       9     2      1        2  ...     -1.34803     -6.915080
# 2135       9     2      2        2  ...      0.60033     -4.257135
#
#      HorzApprAngle ExitSpeed      Angle  Direction  HitSpinRate  Distance  \
# 1346     -0.186707       NaN        NaN        NaN          NaN       NaN
# 1347     -2.006189       NaN        NaN        NaN          NaN       NaN
# 1348     -0.048878       NaN        NaN        NaN          NaN       NaN
# 1349     -0.423694  74.83741 -36.335603 -37.933633          NaN    4.6972
# 1350      0.724276       NaN        NaN        NaN          NaN       NaN
# ...            ...       ...        ...        ...          ...       ...
# 2131     -1.957550       NaN        NaN        NaN          NaN       NaN
# 2132     -0.460913       NaN        NaN        NaN          NaN       NaN
# 2133     -2.688614       NaN        NaN        NaN          NaN       NaN
# 2134     -2.449622       NaN        NaN        NaN          NaN       NaN
# 2135     -0.451014  89.18893  12.291610 -35.922030     2826.931  172.8054
#
#         Bearing  HangTime
# 1346        NaN       NaN
# 1347        NaN       NaN
# 1348        NaN       NaN
# 1349 -21.757954  0.034375
# 1350        NaN       NaN
# ...         ...       ...
# 2131        NaN       NaN
# 2132        NaN       NaN
# 2133        NaN       NaN
# 2134        NaN       NaN
# 2135 -41.369880  1.701729
#
# [790 rows x 41 columns]
